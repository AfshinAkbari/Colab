# %% [markdown]
# <a href="https://colab.research.google.com/github/AfshinAkbari/Colab/blob/main/Youtub_Translator_aigolden2025_03_31Dubbing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title نصب کتابخانه ها
import base64

encoded_url = "aHR0cHM6Ly9naXRodWIuY29tL3lhcmFuYmFyemkvYWlnb2xkZW4tYXVkaW8tdG8tdGV4dC5naXQ="
decoded_url = base64.b64decode(encoded_url.encode()).decode()
# !pip install git+$decoded_url
# !pip install edge_tts
# !pip install yt-dlp
# !pip install pysrt
# !pip install rubberband-cli
# !pip install pydub
# !pip install youtube-transcript-api
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Collecting git+https://github.com/yaranbarzi/aigolden-audio-to-text.git
#   Cloning https://github.com/yaranbarzi/aigolden-audio-to-text.git to /tmp/pip-req-build-pnyejfpx
#   Running command git clone --filter=blob:none --quiet https://github.com/yaranbarzi/aigolden-audio-to-text.git /tmp/pip-req-build-pnyejfpx
#   Resolved https://github.com/yaranbarzi/aigolden-audio-to-text.git to commit 29d2330f2015a263d5ed1ae7bc94f03e307e6ad0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (4.67.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (10.6.0)
# Collecting tiktoken (from openai-whisper==20240930)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: triton>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (3.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->openai-whisper==20240930) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->openai-whisper==20240930) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken->openai-whisper==20240930) (2.32.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->openai-whisper==20240930)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->openai-whisper==20240930)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->openai-whisper==20240930)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->openai-whisper==20240930)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->openai-whisper==20240930)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->openai-whisper==20240930)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->openai-whisper==20240930)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->openai-whisper==20240930)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->openai-whisper==20240930)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->openai-whisper==20240930)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->openai-whisper==20240930) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->openai-whisper==20240930) (3.0.2)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 22.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.4 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20240930-py3-none-any.whl size=803893 sha256=1b68c52c0fa60497dd60ba092baeb2a9721d2e85309ded0c2bbff3966b4f9b10
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n6rq9xb9/wheels/1b/62/e7/818fe183a7eb49f971826e0bccb5d607500ebcbdb259f8d180
# Successfully built openai-whisper
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, openai-whisper
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 openai-whisper-20240930 tiktoken-0.9.0
# Collecting edge_tts
#   Downloading edge_tts-7.0.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /usr/local/lib/python3.11/dist-packages (from edge_tts) (3.11.15)
# Requirement already satisfied: certifi>=2023.11.17 in /usr/local/lib/python3.11/dist-packages (from edge_tts) (2025.1.31)
# Collecting srt<4.0.0,>=3.4.1 (from edge_tts)
#   Downloading srt-3.5.3.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate<1.0.0,>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from edge_tts) (0.9.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from edge_tts) (4.13.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge_tts) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge_tts) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge_tts) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge_tts) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge_tts) (6.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge_tts) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge_tts) (1.18.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.8.0->edge_tts) (3.10)
# Downloading edge_tts-7.0.0-py3-none-any.whl (23 kB)
# Building wheels for collected packages: srt
#   Building wheel for srt (setup.py) ... done
#   Created wheel for srt: filename=srt-3.5.3-py3-none-any.whl size=22427 sha256=a08b167ff855da5f0f98296ccc6941f1963f459bd7fd9a75cfa50a34feea6fb7
#   Stored in directory: /root/.cache/pip/wheels/1f/43/f1/23ee9119497fcb57d9f7046fbf34c6d9027c46a1fa7824cf08
# Successfully built srt
# Installing collected packages: srt, edge_tts
# Successfully installed edge_tts-7.0.0 srt-3.5.3
# Collecting yt-dlp
#   Downloading yt_dlp-2025.3.31-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 12.9 MB/s eta 0:00:00
# Downloading yt_dlp-2025.3.31-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 85.6 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.3.31
# Collecting pysrt
#   Downloading pysrt-1.1.2.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from pysrt) (5.2.0)
# Building wheels for collected packages: pysrt
#   Building wheel for pysrt (setup.py) ... done
#   Created wheel for pysrt: filename=pysrt-1.1.2-py3-none-any.whl size=13443 sha256=d2f2fed24a063d9b8c682ba53e33b3170477ac2f45f55b426ec306c9ea8e4f16
#   Stored in directory: /root/.cache/pip/wheels/2d/b2/df/ea10959920533975b4a74a25a35e6d79655b63f3006611a99f
# Successfully built pysrt
# Installing collected packages: pysrt
# Successfully installed pysrt-1.1.2
# ERROR: Could not find a version that satisfies the requirement rubberband-cli (from versions: none)
# ERROR: No matching distribution found for rubberband-cli
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-1.0.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->youtube-transcript-api) (2025.1.31)
# Downloading youtube_transcript_api-1.0.3-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 73.5 MB/s eta 0:00:00
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-1.0.3
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,381 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,775 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,686 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,978 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,148 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,241 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,092 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,812 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,540 kB]
# Fetched 30.0 MB in 5s (6,622 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 42 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
#@title اتصال به گوگل درایو
#@markdown #### فقط در صورتی اجرا کنید که ویدیوی مورد نظر در گوگل درایو باشد
from google.colab import drive
drive.mount('/content/drive')

# %%
#@title آپلود ویدیو از سه طریق مختلف
#@markdown ### `در صورتی که دانلود از یوتیوب ناموفق بود کوکی های مرورگر را قبل از اجرا پاک کنید`
from google.colab import files
from IPython.display import display
import ipywidgets as widgets
import yt_dlp
import os
import shutil
import glob

# پاکسازی فایل‌های قبلی
for file in glob.glob('input_video*'):
    os.remove(file)
    print(f"فایل {file} حذف شد.")

if os.path.exists('audio.wav'):
    os.remove('audio.wav')
    print("فایل صوتی قبلی حذف شد.")
if os.path.exists('audio.srt'):
    os.remove('audio.srt')
    print("فایل زیرنویس قبلی حذف شد.")
if os.path.exists('dubbing_project'):
    shutil.rmtree('dubbing_project')
    print("پوشه پروژه دوبله قبلی حذف شد.")

upload_method = "یوتیوب" #@param ["حافظه داخلی", "یوتیوب", "گوگل درایو"]
#@markdown #### محل وارد کردن لینک ویدیوی یوتیوب
YT_Link = "https://www.youtube.com/watch?v=Cyv-dgv80kE&t=2913s" #@param {type:"string"}
# ذخیره لینک در متغیر محیطی
os.environ['YT_Link'] = YT_Link
#@markdown #### انتخاب کیفیت ویدیوی یوتیوب
video_quality = "متوسط (480p)" #@param ["بالا", "متوسط (720p)", "متوسط (480p)", "پایین"]
#@markdown #### محل وارد کردن مسیر گوگل درایو
drive_path = "" #@param {type:"string"}

def process_youtube(url, quality):
    if url.strip():
        # حذف فایل‌های قبلی
        for file in glob.glob('input_video*'):
            if os.path.exists(file):
                os.remove(file)

        # تنظیم فرمت مناسب
        if quality == "بالا":
            format_option = 'bestvideo+bestaudio/best'
        elif quality == "متوسط (720p)":
            format_option = 'bestvideo[height<=720]+bestaudio/best[height<=720]'
        elif quality == "متوسط (480p)":
            format_option = 'bestvideo[height<=480]+bestaudio/best[height<=480]'
        else:  # پایین
            format_option = 'best'

        # دانلود ویدیو با نام خاص
        temp_filename = 'temp_video.%(ext)s'
        video_opts = {
            'format': format_option,
            'outtmpl': temp_filename,
            'nocheckcertificate': True,
            'ignoreerrors': False,
            'no_warnings': False,
            'quiet': False
        }

        try:
            with yt_dlp.YoutubeDL(video_opts) as ydl:
                info = ydl.extract_info(url, download=True)
                downloaded_file = ydl.prepare_filename(info)

            print(f"فایل دانلود شده: {downloaded_file}")

            # تغییر نام فایل به input_video.mp4
            if os.path.exists(downloaded_file):
                # استخراج پسوند فایل و حفظ آن
                _, file_extension = os.path.splitext(downloaded_file)

                # تغییر نام فایل با حفظ پسوند
                final_filename = 'input_video' + file_extension
                os.rename(downloaded_file, final_filename)

                print(f"نام فایل به {final_filename} تغییر یافت")

                # اگر پسوند mp4 نیست، تبدیل به mp4
                if file_extension.lower() != '.mp4':
                    os.system(f'ffmpeg -i "{final_filename}" -c copy input_video.mp4 -y')
                    if os.path.exists('input_video.mp4'):
                        os.remove(final_filename)
                        print(f"فایل به فرمت MP4 تبدیل شد")

                # استخراج صدا
                os.system('ffmpeg -i input_video.mp4 -vn audio.wav -y')
                print(f"صدا از ویدیو استخراج شد.")
                return True
            else:
                print("فایل دانلود شده یافت نشد.")
                return False
        except Exception as e:
            print(f"خطا در دانلود: {str(e)}")
            return False
    return False

if upload_method == "یوتیوب" and YT_Link.strip():
    print(f"در حال دانلود ویدیو با کیفیت {video_quality}...")
    success = process_youtube(YT_Link, video_quality)
    if success:
        print(f"ویدیو با کیفیت {video_quality} دانلود شد.")
    else:
        print("دانلود ناموفق بود.")
elif upload_method == "گوگل درایو" and drive_path.strip():
    os.system(f'cp "{drive_path}" input_video.mp4')
    os.system('ffmpeg -i input_video.mp4 -vn audio.wav')
    print("ویدیو و فایل صوتی از گوگل درایو کپی شدند.")
elif upload_method == "حافظه داخلی":
    print("لطفاً ویدیوی خود را آپلود کنید:")
    uploaded = files.upload()
    video_file = next(iter(uploaded.keys()))
    os.system(f'ffmpeg -i "{video_file}" -vn audio.wav')
    os.rename(video_file, 'input_video.mp4')
    print("ویدیو آپلود و فایل صوتی استخراج شد.")

if os.path.exists('input_video.mp4'):
    print("عملیات با موفقیت انجام شد!")
else:
    print("خطا در دانلود ویدیو. لطفاً لینک دیگری را امتحان کنید یا از روش دیگری برای آپلود استفاده کنید.")
# Out:
# در حال دانلود ویدیو با کیفیت متوسط (480p)...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Cyv-dgv80kE&t=2913s
# [youtube] Cyv-dgv80kE: Downloading webpage
# [youtube] Cyv-dgv80kE: Downloading tv client config
# [youtube] Cyv-dgv80kE: Downloading player 73381ccc-main
# [youtube] Cyv-dgv80kE: Downloading tv player API JSON
# [youtube] Cyv-dgv80kE: Downloading ios player API JSON
# [youtube] Cyv-dgv80kE: Downloading m3u8 information
# [info] Cyv-dgv80kE: Downloading 1 format(s): 244+251
# [download] Destination: temp_video.f244.webm
# [download] 100% of  472.85MiB in 00:00:51 at 9.20MiB/s
# [download] Destination: temp_video.f251.webm
# [download] 100% of  225.15MiB in 00:00:04 at 50.98MiB/s
# [Merger] Merging formats into "temp_video.webm"
# Deleting original file temp_video.f244.webm (pass -k to keep)
# Deleting original file temp_video.f251.webm (pass -k to keep)
# فایل دانلود شده: temp_video.webm
# نام فایل به input_video.webm تغییر یافت
# فایل به فرمت MP4 تبدیل شد
# صدا از ویدیو استخراج شد.
# ویدیو با کیفیت متوسط (480p) دانلود شد.
# عملیات با موفقیت انجام شد!

# %%
#@title استخراج متن از فایل صوتی
from google.colab import files
import os
import pysrt
import subprocess
import re
import json
from youtube_transcript_api import YouTubeTranscriptApi

extraction_method = "Transcript" #@param ["Whisper", "آپلود زیرنویس", "Transcript"]
transcript_language = "Auto-detect" #@param ["Auto-detect", "English (EN)", "Persian (FA)", "German (DE)", "French (FR)", "Italian (IT)", "Spanish (ES)", "Chinese (ZH)", "Korean (KO)", "Russian (RU)", "Arabic (AR)", "Japanese (JA)", "Hindi (HI)"]

if extraction_method == "Whisper":
    if os.path.exists('audio.wav'):
        # !whisper "audio.wav" --model large --output_dir ./ --output_format srt
        os.rename("audio.srt", "audio.srt")  # اطمینان از نام فایل صحیح
    else:
        print("لطفاً ابتدا یک فایل صوتی آپلود کنید.")

elif extraction_method == "Transcript":
    # بررسی وجود فایل و شرایط لازم
    if not os.path.exists('input_video.mp4'):
        print("فایل ویدیویی یافت نشد! لطفاً ابتدا یک ویدیو از یوتیوب دانلود کنید.")
    else:
        # دریافت لینک یوتیوب از متغیر محیطی
        youtube_url = os.environ.get('YT_Link', '')

        if not youtube_url:
            print("لینک یوتیوب یافت نشد! لطفاً در سلول آپلود، یک لینک معتبر وارد کنید.")
        else:
            print(f"در حال استخراج زیرنویس از ویدیوی یوتیوب با لینک: {youtube_url}")

            # استخراج شناسه ویدیوی یوتیوب
            video_id = None
            patterns = [
                r'(?:youtube\.com\/(?:[^\/\n\s]+\/\S+\/|(?:v|e(?:mbed)?)\/|\S*?[?&]v=)|youtu\.be\/)([a-zA-Z0-9_-]{11})',
                r'(?:youtube\.com\/shorts\/)([a-zA-Z0-9_-]{11})'
            ]

            for pattern in patterns:
                match = re.search(pattern, youtube_url)
                if match:
                    video_id = match.group(1)
                    break

            if not video_id:
                if 'shorts/' in youtube_url:
                    shorts_id = youtube_url.split('shorts/')[1].split('?')[0].split('&')[0]
                    if len(shorts_id) == 11:
                        video_id = shorts_id
                elif 'youtu.be/' in youtube_url:
                    video_id = youtube_url.split('youtu.be/')[1].split('?')[0].split('&')[0]
                elif 'v=' in youtube_url:
                    video_id = youtube_url.split('v=')[1].split('&')[0].split('?')[0]

            if video_id and len(video_id) == 11:
                print(f"شناسه ویدیو: {video_id}")
            else:
                print(f"نتوانستیم شناسه ویدیو را از لینک {youtube_url} استخراج کنیم.")
                print("لطفاً مطمئن شوید لینک به شکل درستی وارد شده است.")
                exit()

            # نگاشت زبان‌ها به کدهای استاندارد (هماهنگ با سلول ترجمه)
            language_map = {
                "Auto-detect": None,
                "English (EN)": "en",
                "Persian (FA)": "fa",
                "German (DE)": "de",
                "French (FR)": "fr",
                "Italian (IT)": "it",
                "Spanish (ES)": "es",
                "Chinese (ZH)": "zh",
                "Korean (KO)": "ko",
                "Russian (RU)": "ru",
                "Arabic (AR)": "ar",
                "Japanese (JA)": "ja",
                "Hindi (HI)": "hi"
            }
            selected_language = language_map.get(transcript_language)

            # دریافت زیرنویس با YouTube Transcript API
            try:
                print(f"در حال دریافت زیرنویس برای ویدیو با شناسه: {video_id}")

                # دریافت لیست زیرنویس‌ها
                transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

                # چاپ لیست زیرنویس‌های موجود
                print("\nزیرنویس‌های موجود برای این ویدیو:")
                print("----------------------------------------")
                manual_transcripts = []
                generated_transcripts = []
                translatable_transcripts = []

                for transcript in transcript_list:
                    if not transcript.is_generated and not transcript.is_translatable:
                        manual_transcripts.append(f"{transcript.language} ({transcript.language_code}) - Manual")
                    elif transcript.is_generated:
                        generated_transcripts.append(f"{transcript.language} ({transcript.language_code}) - Auto-generated")
                    if transcript.is_translatable:
                        translatable_transcripts.append(f"{transcript.language} ({transcript.language_code}) - Translatable")

                if manual_transcripts:
                    print("زیرنویس‌های دستی (Manually Created):")
                    for t in manual_transcripts:
                        print(f"  - {t}")
                else:
                    print("زیرنویس‌های دستی: هیچ‌کدام")

                if generated_transcripts:
                    print("زیرنویس‌های خودکار (Generated):")
                    for t in generated_transcripts:
                        print(f"  - {t}")
                else:
                    print("زیرنویس‌های خودکار: هیچ‌کدام")

                if translatable_transcripts:
                    print("زیرنویس‌های قابل ترجمه (Translatable):")
                    for t in translatable_transcripts:
                        print(f"  - {t}")
                print("----------------------------------------\n")

                # انتخاب زیرنویس
                if selected_language:  # زبان خاص انتخاب شده
                    transcript_data = YouTubeTranscriptApi.get_transcript(video_id, languages=[selected_language])
                    print(f"زیرنویس به زبان {transcript_language} دریافت شد.")
                else:  # Auto-detect
                    transcript_data = None
                    selected_lang_code = None

                    # پیدا کردن اولین زیرنویس موجود (دستی یا خودکار)
                    for transcript in transcript_list:
                        if transcript.is_generated:
                            print(f"زیرنویس خودکار به زبان {transcript.language} انتخاب شد.")
                            selected_lang_code = transcript.language_code
                            transcript_data = YouTubeTranscriptApi.get_transcript(video_id, languages=[transcript.language_code])
                            break
                        elif not transcript.is_translatable:
                            print(f"زیرنویس دستی به زبان {transcript.language} انتخاب شد.")
                            selected_lang_code = transcript.language_code
                            transcript_data = YouTubeTranscriptApi.get_transcript(video_id, languages=[transcript.language_code])
                            break

                    # اگه هیچ زیرنویسی نبود، ترجمه به انگلیسی
                    if not transcript_data:
                        for transcript in transcript_list:
                            if transcript.is_translatable:
                                print(f"استفاده از زیرنویس ترجمه‌شده به انگلیسی از {transcript.language}")
                                transcript_data = transcript.translate('en').fetch()
                                selected_lang_code = 'en'
                                break

                if transcript_data:
                    print("زیرنویس با موفقیت دریافت شد!")

                    # محاسبه مدت زمان ویدیو
                    result = subprocess.run([
                        'ffprobe', '-v', 'error', '-show_entries', 'format=duration',
                        '-of', 'default=noprint_wrappers=1:nokey=1',
                        'input_video.mp4'
                    ], capture_output=True, text=True)

                    video_duration = float(result.stdout.strip())
                    print(f"مدت زمان ویدیو: {video_duration} ثانیه")

                    # پردازش زیرنویس‌ها
                    processed_data = []
                    for entry in transcript_data:
                        processed_data.append({
                            'start': entry['start'],
                            'duration': entry.get('duration', 0),
                            'text': entry['text']
                        })

                    # مرتب‌سازی بر اساس زمان شروع
                    processed_data.sort(key=lambda x: x['start'])

                    print(f"تعداد زیرنویس‌های اولیه: {len(processed_data)}")

                    # گام 1: رفع تداخل‌های اولیه زمانی بین زیرنویس‌ها
                    cleaned_data = []
                    if processed_data:
                        cleaned_data.append(processed_data[0])
                        for i in range(1, len(processed_data)):
                            current = processed_data[i]
                            previous = cleaned_data[-1]
                            prev_end = previous['start'] + previous['duration']

                            if current['start'] < prev_end:
                                if current['start'] + current['duration'] <= prev_end:
                                    print(f"زیرنویس {i+1} کاملاً با زیرنویس قبلی همپوشانی دارد و ادغام می‌شود")
                                    previous['text'] += " " + current['text']
                                else:
                                    overlap = prev_end - current['start']
                                    new_duration = current['duration'] - overlap

                                    if new_duration > 0.3:
                                        current['start'] = prev_end
                                        current['duration'] = new_duration
                                        cleaned_data.append(current)
                                        print(f"تداخل زمانی اولیه در زیرنویس {i+1} اصلاح شد")
                                    else:
                                        previous['text'] += " " + current['text']
                                        previous['duration'] = max(previous['duration'],
                                                                 (current['start'] + current['duration']) - previous['start'])
                                        print(f"زیرنویس {i+1} به دلیل تداخل زمانی با زیرنویس قبلی ادغام شد")
                            else:
                                cleaned_data.append(current)

                    processed_data = cleaned_data
                    print(f"تعداد زیرنویس‌ها پس از رفع تداخل‌های اولیه: {len(processed_data)}")

                    # گام 2: بررسی شروع دیرهنگام و پایان فراتر از حد
                    first_start_time = processed_data[0]['start'] if processed_data else 0
                    has_early_gap = first_start_time > 0.5
                    early_gap_under_3s = first_start_time < 3.0

                    last_entry = processed_data[-1] if processed_data else {'start': 0, 'duration': 0}
                    last_end_time = last_entry['start'] + last_entry['duration']
                    late_overflow = last_end_time > (video_duration - 0.5)

                    # گام 3: تعیین استراتژی برای مدیریت زمان‌بندی
                    if late_overflow and has_early_gap and early_gap_under_3s:
                        print(f"زیرنویس‌ها به صورت هوشمند به عقب کشیده می‌شوند...")
                        available_space = video_duration - 0.5
                        required_space = last_end_time

                        if required_space > available_space:
                            scale_factor = available_space / required_space
                            print(f"ضریب مقیاس زمانی: {scale_factor:.4f}")
                            for entry in processed_data:
                                entry['start'] = entry['start'] * scale_factor
                                entry['duration'] = entry['duration'] * scale_factor
                        else:
                            time_shift = -first_start_time
                            print(f"انتقال زمانی: {time_shift:.2f} ثانیه")
                            for entry in processed_data:
                                entry['start'] += time_shift
                    elif late_overflow:
                        print("فقط سرریز انتهایی داریم - حذف یا کوتاه کردن زیرنویس‌های انتهایی...")

                    # گام 4: نهایی‌سازی زیرنویس‌ها
                    valid_entries = []
                    for i, entry in enumerate(processed_data):
                        start_time = entry['start']
                        duration = entry['duration']
                        end_time = start_time + duration

                        if start_time < 0:
                            duration += start_time
                            start_time = 0
                            entry['start'] = start_time
                            entry['duration'] = duration

                        if end_time > (video_duration - 0.5):
                            if start_time < (video_duration - 0.5):
                                duration = (video_duration - 0.5) - start_time
                                entry['duration'] = duration
                                valid_entries.append(entry)
                                print(f"زیرنویس شماره {i+1} کوتاه شد (پایان: {end_time:.2f} -> {video_duration - 0.5:.2f})")
                            else:
                                print(f"زیرنویس شماره {i+1} به دلیل خارج بودن از محدوده زمانی ویدیو حذف شد")
                                continue
                        else:
                            valid_entries.append(entry)

                    # گام 5: بررسی مجدد تداخل‌های زمانی
                    if len(valid_entries) > 1:
                        final_entries = [valid_entries[0]]
                        for i in range(1, len(valid_entries)):
                            current = valid_entries[i]
                            previous = final_entries[-1]
                            prev_end = previous['start'] + previous['duration']

                            if current['start'] < prev_end:
                                new_duration = (current['start'] + current['duration']) - prev_end
                                if new_duration > 0.3:
                                    current['start'] = prev_end
                                    current['duration'] = new_duration
                                    final_entries.append(current)
                                    print(f"تداخل زمانی نهایی در زیرنویس {i+1} اصلاح شد")
                                else:
                                    previous['text'] += " " + current['text']
                                    previous['duration'] = (current['start'] + current['duration']) - previous['start']
                                    print(f"زیرنویس {i+1} به دلیل تداخل زمانی نهایی با زیرنویس قبلی ادغام شد")
                            else:
                                final_entries.append(current)
                        valid_entries = final_entries

                    # گام 6: تبدیل به فرمت SRT
                    srt_content = []
                    for i, entry in enumerate(valid_entries):
                        start_time = entry['start']
                        duration = entry['duration']
                        end_time = start_time + duration

                        start_str = '{:02d}:{:02d}:{:02d},{:03d}'.format(
                            int(start_time // 3600),
                            int((start_time % 3600) // 60),
                            int(start_time % 60),
                            int((start_time % 1) * 1000)
                        )
                        end_str = '{:02d}:{:02d}:{:02d},{:03d}'.format(
                            int(end_time // 3600),
                            int((end_time % 3600) // 60),
                            int(end_time % 60),
                            int((end_time % 1) * 1000)
                        )
                        srt_content.append(f"{i+1}\n{start_str} --> {end_str}\n{entry['text']}\n")

                    # ذخیره به فایل SRT
                    with open('audio.srt', 'w', encoding='utf-8') as f:
                        f.write('\n'.join(srt_content))

                    print(f"زیرنویس با موفقیت از یوتیوب استخراج شد و در فایل audio.srt ذخیره شد.")
                    print(f"تعداد زیرنویس‌های نهایی: {len(valid_entries)} (از {len(transcript_data)} زیرنویس اصلی)")
                else:
                    print("متأسفانه هیچ زیرنویسی برای این ویدیو یافت نشد!")

            except Exception as e:
                print(f"خطا در استخراج زیرنویس: {str(e)}")
                print("اگر این ویدیو زیرنویس دارد، مطمئن شوید لینک به درستی وارد شده است.")
                print("مثال لینک‌های قابل قبول: https://www.youtube.com/watch?v=VIDEO_ID یا https://www.youtube.com/shorts/VIDEO_ID")

else:  # آپلود زیرنویس
    print("لطفاً فایل زیرنویس خود را با فرمت .srt آپلود کنید:")
    uploaded = files.upload()
    subtitle_file = next(iter(uploaded.keys()))
    os.rename(subtitle_file, 'audio.srt')
# Out:
# Streaming output truncated to the last 5000 lines.
# تداخل زمانی اولیه در زیرنویس 1547 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1548 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1549 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1550 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1551 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1552 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1553 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1554 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1555 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1556 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1557 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1558 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1559 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1560 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1561 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1562 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1563 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1564 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1565 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1566 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1567 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1568 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1569 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1570 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1571 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1572 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1573 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1574 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1575 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1576 اصلاح شد
# زیرنویس 1577 به دلیل تداخل زمانی با زیرنویس قبلی ادغام شد
# تداخل زمانی اولیه در زیرنویس 1579 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1580 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1581 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1582 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1583 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1584 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1585 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1586 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1587 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1588 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1589 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1590 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1591 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1592 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1593 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1594 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1595 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1596 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1597 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1598 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1599 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1600 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1601 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1602 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1603 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1604 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1605 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1606 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1607 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1608 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1609 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1610 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1611 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1612 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1613 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1614 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1615 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1616 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1617 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1618 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1619 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1620 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1621 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1622 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1623 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1624 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1625 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1626 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1627 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1628 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1629 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1630 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1631 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1632 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1633 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1634 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1635 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1636 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1637 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1638 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1639 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1640 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1641 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1642 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1643 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1644 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1645 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1646 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1647 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1648 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1649 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1650 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1651 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1652 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1653 اصلاح شد
# زیرنویس 1654 کاملاً با زیرنویس قبلی همپوشانی دارد و ادغام می‌شود
# تداخل زمانی اولیه در زیرنویس 1656 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1657 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1658 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1659 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1660 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1661 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1662 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1663 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1664 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1665 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1666 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1667 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1668 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1669 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1670 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1671 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1672 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1673 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1674 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1675 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1676 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1677 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1678 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1679 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1680 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1681 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1682 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1683 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1684 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1685 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1686 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1687 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1688 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1689 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1690 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1691 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1692 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1693 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1694 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1695 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1696 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1697 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1698 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1699 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1700 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1701 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1702 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1703 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1704 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1705 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1706 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1707 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1708 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1709 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1710 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1711 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1712 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1713 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1714 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1715 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1716 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1717 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1718 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1719 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1720 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1721 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1722 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1723 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1724 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1725 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1726 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1727 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1728 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1729 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1730 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1731 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1732 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1733 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1734 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1735 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1736 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1737 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1738 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1739 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1740 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1741 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1742 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1743 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1744 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1745 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1746 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1747 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1748 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1749 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1750 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1751 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1752 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1753 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1754 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1755 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1756 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1757 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1758 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1759 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1760 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1761 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1762 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1763 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1764 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1765 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1766 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1767 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1768 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1769 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1770 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1771 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1772 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1773 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1774 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1775 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1776 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1777 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1778 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1779 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1780 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1781 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1782 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1783 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1784 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1785 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1786 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1787 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1788 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1789 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1790 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1791 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1792 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1793 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1794 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1795 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1796 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1797 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1798 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1799 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1800 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1801 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1802 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1803 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1804 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1805 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1806 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1807 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1808 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1809 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1810 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1811 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1812 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1813 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1814 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1815 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1816 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1817 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1818 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1819 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1820 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1821 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1822 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1823 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1824 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1825 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1826 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1827 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1828 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1829 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1830 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1831 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1832 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1833 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1834 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1835 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1836 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1837 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1838 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1839 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1840 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1841 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1842 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1843 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1844 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1845 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1846 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1847 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1848 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1849 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1850 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1851 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1852 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1853 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1854 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1855 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1856 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1857 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1858 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1859 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1860 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1861 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1862 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1863 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1864 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1865 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1866 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1867 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1868 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1869 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1870 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1871 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1872 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1873 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1874 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1875 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1876 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1877 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1878 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1879 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1880 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1881 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1882 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1883 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1884 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1885 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1886 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1887 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1888 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1889 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1890 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1891 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1892 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1893 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1894 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1895 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1896 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1897 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1898 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1899 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1900 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1901 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1902 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1903 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1904 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1905 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1906 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1907 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1908 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1909 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1910 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1911 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1912 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1913 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1914 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1915 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1916 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1917 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1918 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1919 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1920 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1921 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1922 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1923 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1924 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1925 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1926 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1927 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1928 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1929 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1930 اصلاح شد
# زیرنویس 1931 کاملاً با زیرنویس قبلی همپوشانی دارد و ادغام می‌شود
# تداخل زمانی اولیه در زیرنویس 1933 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1934 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1935 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1936 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1937 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1938 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1939 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1940 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1941 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1942 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1943 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1944 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1945 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1946 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1947 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1948 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1949 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1950 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1951 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1952 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1953 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1954 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1955 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1956 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1957 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1958 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1959 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1960 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1961 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1962 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1963 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1964 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1965 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1966 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1967 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1968 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1969 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1970 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1971 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1972 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1973 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1974 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1975 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1976 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1977 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1978 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1979 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1980 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1981 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1982 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1983 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1984 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1985 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1986 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1987 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1988 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1989 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1990 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1991 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1992 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1993 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1994 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1995 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1996 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1997 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1998 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 1999 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2000 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2001 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2002 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2003 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2004 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2005 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2006 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2007 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2008 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2009 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2010 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2011 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2012 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2013 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2014 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2015 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2016 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2017 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2018 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2019 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2020 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2021 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2022 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2023 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2024 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2025 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2026 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2027 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2028 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2029 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2030 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2031 اصلاح شد
# زیرنویس 2032 کاملاً با زیرنویس قبلی همپوشانی دارد و ادغام می‌شود
# تداخل زمانی اولیه در زیرنویس 2034 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2035 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2036 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2037 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2038 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2039 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2040 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2041 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2042 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2043 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2044 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2045 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2046 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2047 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2048 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2049 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2050 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2051 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2052 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2053 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2054 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2055 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2056 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2057 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2058 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2059 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2060 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2061 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2062 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2063 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2064 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2065 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2066 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2067 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2068 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2069 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2070 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2071 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2072 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2073 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2074 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2075 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2076 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2077 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2078 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2079 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2080 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2081 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2082 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2083 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2084 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2085 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2086 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2087 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2088 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2089 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2090 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2091 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2092 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2093 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2094 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2095 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2096 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2097 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2098 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2099 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2100 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2101 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2102 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2103 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2104 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2105 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2106 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2107 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2108 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2109 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2110 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2111 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2112 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2113 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2114 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2115 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2116 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2117 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2118 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2119 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2120 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2121 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2122 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2123 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2124 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2125 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2126 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2127 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2128 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2129 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2130 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2131 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2132 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2133 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2134 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2135 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2136 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2137 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2138 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2139 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2140 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2141 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2142 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2143 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2144 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2145 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2146 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2147 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2148 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2149 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2150 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2151 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2152 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2153 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2154 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2155 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2156 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2157 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2158 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2159 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2160 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2161 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2162 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2163 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2164 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2165 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2166 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2167 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2168 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2169 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2170 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2171 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2172 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2173 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2174 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2175 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2176 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2177 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2178 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2179 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2180 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2181 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2182 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2183 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2184 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2185 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2186 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2187 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2188 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2189 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2190 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2191 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2192 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2193 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2194 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2195 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2196 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2197 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2198 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2199 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2200 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2201 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2202 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2203 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2204 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2205 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2206 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2207 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2208 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2209 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2210 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2211 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2212 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2213 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2214 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2215 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2216 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2217 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2218 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2219 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2220 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2221 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2222 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2223 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2224 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2225 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2226 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2227 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2228 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2229 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2230 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2231 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2232 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2233 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2234 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2235 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2236 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2237 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2238 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2239 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2240 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2241 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2242 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2243 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2244 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2245 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2246 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2247 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2248 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2249 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2250 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2251 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2252 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2253 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2254 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2255 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2256 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2257 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2258 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2259 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2260 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2261 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2262 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2263 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2264 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2265 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2266 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2267 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2268 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2269 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2270 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2271 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2272 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2273 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2274 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2275 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2276 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2277 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2278 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2279 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2280 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2281 اصلاح شد
# زیرنویس 2282 کاملاً با زیرنویس قبلی همپوشانی دارد و ادغام می‌شود
# تداخل زمانی اولیه در زیرنویس 2284 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2285 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2286 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2287 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2288 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2289 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2290 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2291 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2292 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2293 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2294 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2295 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2296 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2297 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2298 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2299 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2300 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2301 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2302 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2303 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2304 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2305 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2306 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2307 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2308 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2309 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2310 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2311 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2312 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2313 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2314 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2315 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2316 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2317 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2318 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2319 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2320 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2321 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2322 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2323 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2324 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2325 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2326 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2327 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2328 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2329 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2330 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2331 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2332 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2333 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2334 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2335 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2336 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2337 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2338 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2339 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2340 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2341 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2342 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2343 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2344 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2345 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2346 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2347 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2348 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2349 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2350 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2351 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2352 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2353 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2354 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2355 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2356 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2357 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2358 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2359 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2360 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2361 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2362 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2363 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2364 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2365 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2366 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2367 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2368 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2369 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2370 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2371 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2372 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2373 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2374 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2375 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2376 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2377 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2378 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2379 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2380 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2381 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2382 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2383 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2384 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2385 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2386 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2387 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2388 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2389 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2390 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2391 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2392 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2393 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2394 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2395 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2396 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2397 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2398 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2399 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2400 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2401 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2402 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2403 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2404 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2405 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2406 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2407 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2408 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2409 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2410 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2411 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2412 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2413 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2414 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2415 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2416 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2417 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2418 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2419 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2420 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2421 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2422 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2423 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2424 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2425 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2426 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2427 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2428 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2429 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2430 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2431 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2432 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2433 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2434 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2435 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2436 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2437 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2438 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2439 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2440 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2441 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2442 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2443 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2444 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2445 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2446 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2447 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2448 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2449 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2450 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2451 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2452 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2453 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2454 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2455 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2456 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2457 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2458 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2459 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2460 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2461 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2462 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2463 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2464 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2465 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2466 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2467 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2468 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2469 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2470 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2471 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2472 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2473 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2474 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2475 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2476 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2477 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2478 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2479 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2480 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2481 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2482 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2483 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2484 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2485 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2486 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2487 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2488 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2489 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2490 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2491 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2492 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2493 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2494 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2495 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2496 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2497 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2498 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2499 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2500 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2501 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2502 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2503 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2504 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2505 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2506 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2507 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2508 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2509 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2510 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2511 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2512 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2513 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2514 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2515 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2516 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2517 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2518 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2519 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2520 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2521 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2522 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2523 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2524 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2525 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2526 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2527 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2528 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2529 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2530 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2531 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2532 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2533 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2534 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2535 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2536 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2537 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2538 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2539 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2540 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2541 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2542 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2543 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2544 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2545 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2546 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2547 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2548 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2549 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2550 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2551 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2552 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2553 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2554 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2555 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2556 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2557 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2558 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2559 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2560 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2561 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2562 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2563 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2564 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2565 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2566 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2567 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2568 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2569 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2570 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2571 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2572 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2573 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2574 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2575 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2576 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2577 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2578 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2579 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2580 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2581 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2582 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2583 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2584 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2585 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2586 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2587 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2588 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2589 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2590 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2591 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2592 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2593 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2594 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2595 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2596 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2597 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2598 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2599 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2600 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2601 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2602 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2603 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2604 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2605 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2606 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2607 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2608 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2609 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2610 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2611 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2612 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2613 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2614 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2615 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2616 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2617 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2618 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2619 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2620 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2621 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2622 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2623 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2624 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2625 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2626 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2627 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2628 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2629 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2630 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2631 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2632 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2633 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2634 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2635 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2636 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2637 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2638 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2639 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2640 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2641 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2642 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2643 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2644 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2645 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2646 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2647 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2648 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2649 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2650 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2651 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2652 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2653 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2654 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2655 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2656 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2657 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2658 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2659 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2660 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2661 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2662 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 2663 اصلاح شد
# ...
# تداخل زمانی اولیه در زیرنویس 6206 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6207 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6208 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6209 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6210 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6211 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6212 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6213 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6214 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6215 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6216 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6217 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6218 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6219 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6220 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6221 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6222 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6223 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6224 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6225 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6226 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6227 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6228 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6229 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6230 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6231 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6232 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6233 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6234 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6235 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6236 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6237 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6238 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6239 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6240 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6241 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6242 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6243 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6244 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6245 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6246 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6247 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6248 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6249 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6250 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6251 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6252 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6253 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6254 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6255 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6256 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6257 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6258 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6259 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6260 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6261 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6262 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6263 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6264 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6265 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6266 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6267 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6268 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6269 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6270 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6271 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6272 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6273 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6274 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6275 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6276 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6277 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6278 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6279 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6280 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6281 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6282 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6283 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6284 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6285 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6286 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6287 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6288 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6289 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6290 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6291 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6292 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6293 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6294 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6295 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6296 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6297 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6298 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6299 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6300 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6301 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6302 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6303 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6304 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6305 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6306 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6307 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6308 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6309 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6310 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6311 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6312 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6313 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6314 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6315 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6316 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6317 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6318 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6319 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6320 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6321 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6322 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6323 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6324 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6325 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6326 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6327 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6328 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6329 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6330 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6331 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6332 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6333 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6334 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6335 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6336 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6337 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6338 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6339 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6340 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6341 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6342 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6343 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6344 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6345 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6346 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6347 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6348 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6349 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6350 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6351 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6352 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6353 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6354 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6355 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6356 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6357 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6358 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6359 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6360 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6361 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6362 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6363 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6364 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6365 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6366 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6367 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6368 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6369 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6370 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6371 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6372 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6373 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6374 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6375 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6376 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6377 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6378 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6379 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6380 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6381 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6382 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6383 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6384 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6385 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6386 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6387 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6388 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6389 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6390 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6391 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6392 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6393 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6394 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6395 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6396 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6397 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6398 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6399 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6400 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6401 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6402 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6403 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6404 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6405 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6406 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6407 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6408 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6409 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6410 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6411 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6412 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6413 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6414 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6415 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6416 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6417 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6418 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6419 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6420 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6421 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6422 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6423 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6424 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6425 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6426 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6427 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6428 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6429 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6430 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6431 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6432 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6433 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6434 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6435 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6436 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6437 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6438 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6439 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6440 اصلاح شد
# زیرنویس 6441 کاملاً با زیرنویس قبلی همپوشانی دارد و ادغام می‌شود
# تداخل زمانی اولیه در زیرنویس 6443 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6444 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6445 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6446 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6447 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6448 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6449 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6450 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6451 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6452 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6453 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6454 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6455 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6456 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6457 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6458 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6459 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6460 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6461 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6462 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6463 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6464 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6465 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6466 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6467 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6468 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6469 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6470 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6471 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6472 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6473 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6474 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6475 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6476 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6477 اصلاح شد
# زیرنویس 6478 به دلیل تداخل زمانی با زیرنویس قبلی ادغام شد
# تداخل زمانی اولیه در زیرنویس 6480 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6481 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6482 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6483 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6484 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6485 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6486 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6487 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6488 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6489 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6490 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6491 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6492 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6493 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6494 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6495 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6496 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6497 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6498 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6499 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6500 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6501 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6502 اصلاح شد
# زیرنویس 6503 کاملاً با زیرنویس قبلی همپوشانی دارد و ادغام می‌شود
# تداخل زمانی اولیه در زیرنویس 6505 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6506 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6507 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6508 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6509 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6510 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6511 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6512 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6513 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6514 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6515 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6516 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6517 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6518 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6519 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6520 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6521 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6522 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6523 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6524 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6525 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6526 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6527 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6528 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6529 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6530 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6531 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6532 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6533 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6534 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6535 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6536 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6537 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6538 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6539 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6540 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6541 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6542 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6543 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6544 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6545 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6546 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6547 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6548 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6549 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6550 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6551 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6552 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6553 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6554 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6555 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6556 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6557 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6558 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6559 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6560 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6561 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6562 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6563 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6564 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6565 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6566 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6567 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6568 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6569 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6570 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6571 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6572 اصلاح شد
# تداخل زمانی اولیه در زیرنویس 6573 اصلاح شد
# زیرنویس 6574 کاملاً با زیرنویس قبلی همپوشانی دارد و ادغام می‌شود
# تعداد زیرنویس‌ها پس از رفع تداخل‌های اولیه: 6542
# زیرنویس با موفقیت از یوتیوب استخراج شد و در فایل audio.srt ذخیره شد.
# تعداد زیرنویس‌های نهایی: 6542 (از 6574 زیرنویس اصلی)

# %%
#@title ترجمه زیرنویس
import pysrt
import google.generativeai as genai
from tqdm.notebook import tqdm
import time
from tenacity import retry, stop_after_attempt, wait_exponential
from google.colab import files
import os
import subprocess
import json

translation_method = "هوش مصنوعی" #@param ["هوش مصنوعی", "آپلود زیرنویس بصورت دستی"]
source_language = "Auto-detect" #@param ["Auto-detect", "English (EN)", "Persian (FA)", "German (DE)", "French (FR)", "Italian (IT)", "Spanish (ES)", "Chinese (ZH)", "Korean (KO)", "Russian (RU)", "Arabic (AR)", "Japanese (JA)", "Hindi (HI)"]
target_language = "Persian (FA)" #@param ["Persian (FA)", "English (EN)", "German (DE)", "French (FR)", "Italian (IT)", "Spanish (ES)", "Chinese (ZH)", "Korean (KO)", "Russian (RU)", "Arabic (AR)", "Japanese (JA)", "Hindi (HI)"]

# تابع برای اصلاح و بهینه‌سازی زیرنویس (مشابه Transcript)
def optimize_subtitles(subs, video_duration):
    processed_data = []
    for sub in subs:
        start_time = sub.start.to_time()
        end_time = sub.end.to_time()
        start_seconds = start_time.hour * 3600 + start_time.minute * 60 + start_time.second + start_time.microsecond / 1000000
        end_seconds = end_time.hour * 3600 + end_time.minute * 60 + end_time.second + end_time.microsecond / 1000000
        duration = end_seconds - start_seconds
        processed_data.append({
            'start': start_seconds,
            'duration': duration if duration > 0 else 0.1,  # حداقل مدت زمان 0.1 ثانیه
            'text': sub.text
        })

    # مرتب‌سازی بر اساس زمان شروع
    processed_data.sort(key=lambda x: x['start'])

    # گام 1: رفع تداخل‌های اولیه زمانی
    cleaned_data = []
    if processed_data:
        cleaned_data.append(processed_data[0])
        for i in range(1, len(processed_data)):
            current = processed_data[i]
            previous = cleaned_data[-1]
            prev_end = previous['start'] + previous['duration']

            if current['start'] < prev_end:
                if current['start'] + current['duration'] <= prev_end:
                    print(f"زیرنویس {i+1} کاملاً با قبلی همپوشانی دارد و ادغام می‌شود")
                    previous['text'] += " " + current['text']
                else:
                    overlap = prev_end - current['start']
                    new_duration = current['duration'] - overlap
                    if new_duration > 0.3:
                        current['start'] = prev_end
                        current['duration'] = new_duration
                        cleaned_data.append(current)
                        print(f"تداخل زمانی در زیرنویس {i+1} اصلاح شد")
                    else:
                        previous['text'] += " " + current['text']
                        previous['duration'] = max(previous['duration'], (current['start'] + current['duration']) - previous['start'])
                        print(f"زیرنویس {i+1} به دلیل تداخل ادغام شد")
            else:
                cleaned_data.append(current)

    processed_data = cleaned_data

    # گام 2: بررسی شروع دیرهنگام و پایان فراتر از حد
    first_start_time = processed_data[0]['start'] if processed_data else 0
    has_early_gap = first_start_time > 0.5
    early_gap_under_3s = first_start_time < 3.0
    last_entry = processed_data[-1] if processed_data else {'start': 0, 'duration': 0}
    last_end_time = last_entry['start'] + last_entry['duration']
    late_overflow = last_end_time > (video_duration - 0.5)

    # گام 3: تنظیم زمان‌بندی
    if late_overflow and has_early_gap and early_gap_under_3s:
        print("زیرنویس‌ها به صورت هوشمند به عقب کشیده می‌شوند...")
        available_space = video_duration - 0.5
        required_space = last_end_time
        if required_space > available_space:
            scale_factor = available_space / required_space
            print(f"ضریب مقیاس زمانی: {scale_factor:.4f}")
            for entry in processed_data:
                entry['start'] *= scale_factor
                entry['duration'] *= scale_factor
        else:
            time_shift = -first_start_time
            print(f"انتقال زمانی: {time_shift:.2f} ثانیه")
            for entry in processed_data:
                entry['start'] += time_shift
    elif late_overflow:
        print("سرریز انتهایی داریم - کوتاه کردن زیرنویس‌های انتهایی...")

    # گام 4: نهایی‌سازی
    valid_entries = []
    for i, entry in enumerate(processed_data):
        start_time = entry['start']
        duration = entry['duration']
        end_time = start_time + duration

        if start_time < 0:
            duration += start_time
            start_time = 0
            entry['start'] = start_time
            entry['duration'] = duration

        if end_time > (video_duration - 0.5):
            if start_time < (video_duration - 0.5):
                duration = (video_duration - 0.5) - start_time
                entry['duration'] = duration
                valid_entries.append(entry)
                print(f"زیرنویس شماره {i+1} کوتاه شد")
            else:
                print(f"زیرنویس شماره {i+1} حذف شد")
                continue
        else:
            valid_entries.append(entry)

    # گام 5: بررسی مجدد تداخل‌ها
    if len(valid_entries) > 1:
        final_entries = [valid_entries[0]]
        for i in range(1, len(valid_entries)):
            current = valid_entries[i]
            previous = final_entries[-1]
            prev_end = previous['start'] + previous['duration']

            if current['start'] < prev_end:
                new_duration = (current['start'] + current['duration']) - prev_end
                if new_duration > 0.3:
                    current['start'] = prev_end
                    current['duration'] = new_duration
                    final_entries.append(current)
                    print(f"تداخل نهایی در زیرنویس {i+1} اصلاح شد")
                else:
                    previous['text'] += " " + current['text']
                    previous['duration'] = (current['start'] + current['duration']) - previous['start']
                    print(f"زیرنویس {i+1} ادغام شد")
            else:
                final_entries.append(current)
        valid_entries = final_entries

    # تبدیل به فرمت SRT
    srt_content = []
    for i, entry in enumerate(valid_entries):
        start_time = entry['start']
        end_time = start_time + entry['duration']
        start_str = '{:02d}:{:02d}:{:02d},{:03d}'.format(
            int(start_time // 3600),
            int((start_time % 3600) // 60),
            int(start_time % 60),
            int((start_time % 1) * 1000)
        )
        end_str = '{:02d}:{:02d}:{:02d},{:03d}'.format(
            int(end_time // 3600),
            int((end_time % 3600) // 60),
            int(end_time % 60),
            int((end_time % 1) * 1000)
        )
        srt_content.append(f"{i+1}\n{start_str} --> {end_str}\n{entry['text']}\n")

    with open('audio_fa.srt', 'w', encoding='utf-8') as f:
        f.write('\n'.join(srt_content))

    print(f"زیرنویس بهینه‌سازی شد - تعداد خطوط نهایی: {len(valid_entries)}")
    return len(valid_entries)

if translation_method == "هوش مصنوعی":
    #@markdown  **لطفاً کلید خود را در کادر زیر وارد کنید (API KEY)**
    GOOGLE_API_KEY = "AIzaSyAWSXIxUXMaZUS1zw84qTWUh8z1vYU8h3I" #@param {type:"string"}

    if not GOOGLE_API_KEY:
        print("هشدار: کلید API وارد نشده است.")
    else:
        genai.configure(api_key=GOOGLE_API_KEY)
        print("کلید API با موفقیت پیکربندی شد.")

        filename = '/content/audio.srt'
        output_filename = '/content/audio_translated.srt'

        @retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
        def translate_subtitle_with_retry(text, source_lang=None):
            model = genai.GenerativeModel('gemini-1.5-flash', safety_settings={
                genai.types.HarmCategory.HARM_CATEGORY_HARASSMENT: genai.types.HarmBlockThreshold.BLOCK_NONE,
                genai.types.HarmCategory.HARM_CATEGORY_HATE_SPEECH: genai.types.HarmBlockThreshold.BLOCK_NONE,
                genai.types.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: genai.types.HarmBlockThreshold.BLOCK_NONE,
                genai.types.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: genai.types.HarmBlockThreshold.BLOCK_NONE,
            })

            language_map = {
                "Persian (FA)": "فارسی",
                "English (EN)": "English",
                "German (DE)": "German",
                "French (FR)": "French",
                "Italian (IT)": "Italian",
                "Spanish (ES)": "Spanish",
                "Chinese (ZH)": "Chinese",
                "Korean (KO)": "Korean",
                "Russian (RU)": "Russian",
                "Arabic (AR)": "Arabic",
                "Japanese (JA)": "Japanese",
                "Hindi (HI)": "Hindi"
            }
            target_lang_name = language_map.get(target_language, "English")

            language_codes = {
                "Auto-detect": None,
                "English (EN)": "en",
                "Persian (FA)": "fa",
                "German (DE)": "de",
                "French (FR)": "fr",
                "Italian (IT)": "it",
                "Spanish (ES)": "es",
                "Chinese (ZH)": "zh",
                "Korean (KO)": "ko",
                "Russian (RU)": "ru",
                "Arabic (AR)": "ar",
                "Japanese (JA)": "ja",
                "Hindi (HI)": "hi"
            }
            source_lang_code = language_codes.get(source_language) if source_lang is None else source_lang

            if source_lang_code is None:
                prompt = f"""Instruction:
                1. Detect the language of the following text.
                2. Translate the text to {target_lang_name} with the same tone.
                3. Use appropriate punctuation where necessary.
                4. No additional explanation or text beyond the translation.
                Text to translate:
                {text}"""
            else:
                prompt = f"""Instruction:
                1. The text is in {language_map.get(source_language, 'English')}.
                2. Translate the text to {target_lang_name} with the same tone.
                3. Use appropriate punctuation where necessary.
                4. No additional explanation or text beyond the translation.
                Text to translate:
                {text}"""

            if target_language == "Persian (FA)":
                prompt = f"""دستورالعمل:
                1. {'زبان متن را تشخیص بده' if source_lang_code is None else f'متن به {language_map.get(source_language)} است'}
                2. فقط متن را به فارسی عامیانه و لحن خودمونی ترجمه کن
                3. هرجا لازمه از نقطه و کاما و علائم نگارشی استفاده کن
                4. اضافه گویی در ترجمه ممنوع
                متن برای ترجمه:
                {text}"""

            response = model.generate_content(prompt)
            time.sleep(3)
            return response.text

        try:
            subs = pysrt.open(filename)
            with tqdm(total=len(subs), desc="ترجمه زیرنویس") as pbar:
                for i, sub in enumerate(subs):
                    sub.text = translate_subtitle_with_retry(sub.text, source_language if source_language != "Auto-detect" else None)
                    pbar.update(1)
            subs.save(output_filename, encoding='utf-8')
            os.rename(output_filename, 'audio_fa.srt')
            print(f"\nترجمه از {source_language} به {target_language} با موفقیت به پایان رسید!")
        except Exception as e:
            print(f"خطا در خواندن فایل زیرنویس: {str(e)}")

else:  # آپلود زیرنویس بصورت دستی
    print("لطفاً فایل زیرنویس ترجمه شده خود را با فرمت .srt آپلود کنید:")
    uploaded = files.upload()
    subtitle_file = next(iter(uploaded.keys()))
    os.rename(subtitle_file, 'audio_fa.srt')

    # محاسبه مدت زمان ویدیو
    result = subprocess.run([
        'ffprobe', '-v', 'error', '-show_entries', 'format=duration',
        '-of', 'default=noprint_wrappers=1:nokey=1', 'input_video.mp4'
    ], capture_output=True, text=True)
    video_duration = float(result.stdout.strip())
    print(f"مدت زمان ویدیو: {video_duration} ثانیه")

    # خواندن و بهینه‌سازی زیرنویس آپلود شده
    try:
        subs = pysrt.open('audio_fa.srt', encoding='utf-8')
        optimize_subtitles(subs, video_duration)
        print("زیرنویس آپلود شده با موفقیت بهینه‌سازی شد.")
    except Exception as e:
        print(f"خطا در پردازش زیرنویس آپلود شده: {str(e)}")
# Out:
# کلید API با موفقیت پیکربندی شد.
# ترجمه زیرنویس:   0%|          | 0/6542 [00:00<?, ?it/s]

# %%
#@title ساخت سگمنت‌های صوتی با زمان‌بندی دقیق (بهبود یافته)
import edge_tts
import asyncio
import pysrt
import os
import subprocess
import traceback
from pydub import AudioSegment

os.makedirs('dubbing_project/dubbed_segments', exist_ok=True)

# استخراج کد زبان از voice_choice برای نام فایل
voice_choice = "فرید (FA)" #@param ["فرید (FA)", "دلارا (FA)", "Jenny (EN)", "Guy (EN)", "Katja (DE)", "Conrad (DE)", "Elvira (ES)", "Alvaro (ES)", "Denise (FR)", "Henri (FR)", "Nanami (JA)", "Keita (JA)", "SunHi (KO)", "InJoon (KO)", "Xiaoxiao (ZH)", "Yunyang (ZH)", "Svetlana (RU)", "Dmitry (RU)", "Zariyah (AR)", "Hamed (AR)", "Isabella (IT)", "Diego (IT)", "Madhur (HI)", "Swara (HI)"]
voice_code = voice_choice.split("(")[1].split(")")[0] if "(" in voice_choice else "FA"
output_filename = f'final_dubbed_video_{voice_code}.mp4'

# تعریف گوینده‌ها برای همه زبان‌ها
VOICE_MAP = {
    # فارسی
    "فرید (FA)": "fa-IR-FaridNeural",
    "دلارا (FA)": "fa-IR-DilaraNeural",
    # انگلیسی
    "Jenny (EN)": "en-US-JennyNeural",
    "Guy (EN)": "en-US-GuyNeural",
    # آلمانی
    "Katja (DE)": "de-DE-KatjaNeural",
    "Conrad (DE)": "de-DE-ConradNeural",
    # فرانسوی
    "Denise (FR)": "fr-FR-DeniseNeural",
    "Henri (FR)": "fr-FR-HenriNeural",
    # ایتالیایی
    "Isabella (IT)": "it-IT-IsabellaNeural",
    "Diego (IT)": "it-IT-DiegoNeural",
    # اسپانیایی
    "Elvira (ES)": "es-ES-ElviraNeural",
    "Alvaro (ES)": "es-ES-AlvaroNeural",
    # چینی
    "Xiaoxiao (ZH)": "zh-CN-XiaoxiaoNeural",
    "Yunyang (ZH)": "zh-CN-YunyangNeural",
    # کره‌ای
    "SunHi (KO)": "ko-KR-SunHiNeural",
    "InJoon (KO)": "ko-KR-InJoonNeural",
    # روسی
    "Svetlana (RU)": "ru-RU-SvetlanaNeural",
    "Dmitry (RU)": "ru-RU-DmitryNeural",
    # عربی
    "Zariyah (AR)": "ar-SA-ZariyahNeural",
    "Hamed (AR)": "ar-SA-HamedNeural",
    # ژاپنی
    "Nanami (JA)": "ja-JP-NanamiNeural",
    "Keita (JA)": "ja-JP-KeitaNeural",
    # هندی
    "Madhur (HI)": "hi-IN-MadhurNeural",
    "Swara (HI)": "hi-IN-SwaraNeural"
}

async def generate_speech():
    # نصب rubberband-cli اگر نصب نیست
    try:
        subprocess.run(['apt-get', 'install', '-y', 'rubberband-cli'], check=True)
        print("rubberband-cli با موفقیت نصب شد.")
    except Exception as e:
        print(f"خطا در نصب rubberband-cli: {str(e)}")
        print("در حال ادامه با روش جایگزین...")

    try:
        subs = pysrt.open('/content/audio_fa.srt', encoding='utf-8')
    except UnicodeDecodeError:
        # اگر utf-8 نبود، سعی کنید با latin-1
        subs = pysrt.open('/content/audio_fa.srt', encoding='latin-1')
    except Exception as e:
        print(f"خطا در خواندن فایل زیرنویس: {str(e)}")
        print("در حال تلاش با فرمت دیگر...")
        try:
            # تبدیل فایل زیرنویس به utf-8
            subprocess.run(['iconv', '-f', 'ISO-8859-1', '-t', 'UTF-8', '/content/audio_fa.srt', '-o', '/content/audio_fa_utf8.srt'])
            subs = pysrt.open('/content/audio_fa_utf8.srt')
            print("فایل زیرنویس با موفقیت به UTF-8 تبدیل شد.")
        except Exception as e2:
            print(f"باز هم خطا در خواندن فایل زیرنویس: {str(e2)}")
            return

    selected_voice = VOICE_MAP.get(voice_choice)
    if not selected_voice:
        print(f"گوینده انتخاب شده '{voice_choice}' در لیست موجود نیست. لطفاً یک گوینده معتبر انتخاب کنید.")
        return

    print(f"شروع تولید سگمنت‌های صوتی با صدای {voice_choice} ({selected_voice})...")

    # ایجاد فایل log برای ثبت وضعیت سگمنت‌ها
    with open('dubbing_project/segments_log.txt', 'w', encoding='utf-8') as log_file:
        log_file.write("=== گزارش وضعیت سگمنت‌های صوتی ===\n\n")

        for i, sub in enumerate(subs):
            try:
                # ثبت اطلاعات زیرنویس در لاگ
                log_file.write(f"سگمنت {i+1}:\n")
                log_file.write(f"  متن: {sub.text}\n")
                log_file.write(f"  زمان شروع: {sub.start}\n")
                log_file.write(f"  زمان پایان: {sub.end}\n")

                # محاسبه مدت زمان دقیق
                start_time = sub.start.seconds + sub.start.minutes * 60 + sub.start.hours * 3600 + sub.start.milliseconds/1000
                end_time = sub.end.seconds + sub.end.minutes * 60 + sub.end.hours * 3600 + sub.end.milliseconds/1000
                target_duration = end_time - start_time

                # اگر مدت زمان صفر یا منفی باشد، اصلاح شود
                if target_duration <= 0:
                    log_file.write(f"  هشدار: مدت زمان نامعتبر ({target_duration}s)، تنظیم به 1 ثانیه\n")
                    target_duration = 1.0

                log_file.write(f"  مدت زمان هدف: {target_duration:.2f}s\n")

                # تولید صدا با Edge TTS
                communicate = edge_tts.Communicate(sub.text, selected_voice)
                await communicate.save(f"dubbing_project/dubbed_segments/temp_{i+1}.mp3")
                log_file.write(f"  فایل MP3 اولیه ایجاد شد\n")

                # استفاده از ffmpeg برای تبدیل به wav
                try:
                    subprocess.run([
                        'ffmpeg', '-i', f"dubbing_project/dubbed_segments/temp_{i+1}.mp3",
                        '-acodec', 'pcm_s16le', '-ar', '44100', '-ac', '2',
                        '-y', f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav"
                    ], check=True)
                    log_file.write(f"  تبدیل به WAV با موفقیت انجام شد\n")
                except subprocess.CalledProcessError:
                    log_file.write(f"  خطا در تبدیل به WAV، در حال استفاده از pydub\n")
                    # استفاده از pydub به عنوان جایگزین
                    sound = AudioSegment.from_mp3(f"dubbing_project/dubbed_segments/temp_{i+1}.mp3")
                    sound.export(f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav", format="wav")
                    log_file.write(f"  تبدیل به WAV با pydub با موفقیت انجام شد\n")

                # محاسبه مدت زمان اصلی فایل صوتی
                try:
                    result = subprocess.run([
                        'ffprobe', '-v', 'error', '-show_entries', 'format=duration',
                        '-of', 'default=noprint_wrappers=1:nokey=1',
                        f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav"
                    ], capture_output=True, text=True, check=True)
                    original_duration = float(result.stdout.strip())
                    log_file.write(f"  مدت زمان اصلی: {original_duration:.2f}s\n")
                except:
                    # اگر ffprobe کار نکرد، از pydub استفاده کن
                    sound = AudioSegment.from_file(f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav")
                    original_duration = len(sound) / 1000.0  # تبدیل میلی‌ثانیه به ثانیه
                    log_file.write(f"  مدت زمان اصلی (با pydub): {original_duration:.2f}s\n")

                # محاسبه ضریب سرعت
                speed_factor = original_duration / target_duration

                # محدود کردن ضریب سرعت برای جلوگیری از خطا
                if speed_factor < 0.5:
                    speed_factor = 0.5
                    log_file.write(f"  هشدار: ضریب سرعت خیلی کم، تنظیم به 0.5\n")
                elif speed_factor > 2.0:
                    speed_factor = 2.0
                    log_file.write(f"  هشدار: ضریب سرعت خیلی زیاد، تنظیم به 2.0\n")

                log_file.write(f"  ضریب سرعت نهایی: {speed_factor}\n")

                # روش 1: استفاده از rubberband (اگر نصب باشد)
                try:
                    subprocess.run([
                        'ffmpeg', '-i', f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav",
                        '-filter:a', f'rubberband=tempo={speed_factor}',
                        '-y', f"dubbing_project/dubbed_segments/dub_{i+1}.wav"
                    ], check=True)
                    log_file.write(f"  تغییر سرعت با rubberband با موفقیت انجام شد\n")
                except:
                    # روش 2: استفاده از فیلتر atempo فقط در محدوده 0.5 تا 2.0
                    log_file.write(f"  خطا در استفاده از rubberband، در حال استفاده از atempo\n")
                    try:
                        subprocess.run([
                            'ffmpeg', '-i', f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav",
                            '-filter:a', f'atempo={speed_factor}',
                            '-y', f"dubbing_project/dubbed_segments/dub_{i+1}.wav"
                        ], check=True)
                        log_file.write(f"  تغییر سرعت با atempo با موفقیت انجام شد\n")
                    except:
                        # روش 3: استفاده از pydub
                        log_file.write(f"  خطا در استفاده از atempo، در حال استفاده از pydub\n")
                        try:
                            # کپی فایل اصلی بدون تغییر سرعت
                            subprocess.run([
                                'cp', f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav",
                                f"dubbing_project/dubbed_segments/dub_{i+1}.wav"
                            ], check=True)
                            log_file.write(f"  استفاده از فایل اصلی بدون تغییر سرعت\n")
                        except:
                            log_file.write(f"  همه روش‌ها با خطا مواجه شدند\n")
                            raise Exception("خطا در ایجاد فایل صوتی")

                # اطمینان از وجود فایل نهایی
                if not os.path.exists(f"dubbing_project/dubbed_segments/dub_{i+1}.wav"):
                    log_file.write(f"  خطا: فایل نهایی ایجاد نشد!\n")
                    # ایجاد یک فایل صدای خالی به عنوان پشتیبان
                    silent_audio = AudioSegment.silent(duration=int(target_duration * 1000))
                    silent_audio.export(f"dubbing_project/dubbed_segments/dub_{i+1}.wav", format="wav")
                    log_file.write(f"  یک فایل سکوت به عنوان جایگزین ایجاد شد\n")
                else:
                    # بررسی مدت زمان فایل نهایی
                    try:
                        result = subprocess.run([
                            'ffprobe', '-v', 'error', '-show_entries', 'format=duration',
                            '-of', 'default=noprint_wrappers=1:nokey=1',
                            f"dubbing_project/dubbed_segments/dub_{i+1}.wav"
                        ], capture_output=True, text=True)
                        final_duration = float(result.stdout.strip())
                        log_file.write(f"  مدت زمان نهایی: {final_duration:.2f}s\n")
                    except:
                        log_file.write(f"  نمی‌توان مدت زمان فایل نهایی را تعیین کرد\n")

                # پاکسازی فایل‌های موقت
                if os.path.exists(f"dubbing_project/dubbed_segments/temp_{i+1}.mp3"):
                    os.remove(f"dubbing_project/dubbed_segments/temp_{i+1}.mp3")
                if os.path.exists(f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav"):
                    os.remove(f"dubbing_project/dubbed_segments/temp_wav_{i+1}.wav")

                log_file.write(f"  بخش {i+1} با موفقیت ساخته شد\n\n")
                print(f"بخش {i+1} از {len(subs)} ساخته شد")

            except Exception as e:
                # در صورت خطا، ایجاد یک فایل صدای خالی
                log_file.write(f"  خطای کلی: {str(e)}\n")
                log_file.write(f"  جزئیات خطا: {traceback.format_exc()}\n")
                log_file.write(f"  در حال ایجاد فایل سکوت به عنوان جایگزین\n")

                try:
                    # محاسبه مدت زمان دقیق
                    start_time = sub.start.seconds + sub.start.minutes * 60 + sub.start.hours * 3600 + sub.start.milliseconds/1000
                    end_time = sub.end.seconds + sub.end.minutes * 60 + sub.end.hours * 3600 + sub.end.milliseconds/1000
                    target_duration = max(end_time - start_time, 0.5)  # حداقل 0.5 ثانیه

                    # ایجاد فایل سکوت
                    silent_audio = AudioSegment.silent(duration=int(target_duration * 1000))
                    silent_audio.export(f"dubbing_project/dubbed_segments/dub_{i+1}.wav", format="wav")
                    log_file.write(f"  فایل سکوت با مدت زمان {target_duration:.2f}s ایجاد شد\n\n")
                except Exception as e2:
                    log_file.write(f"  خطا در ایجاد فایل سکوت: {str(e2)}\n\n")
                    print(f"خطا در پردازش بخش {i+1}: {str(e)}")

    print(f"تمام سگمنت‌های صوتی با صدای {voice_choice} ساخته شدند!")
    print(f"برای اطلاعات بیشتر، فایل گزارش در dubbing_project/segments_log.txt را بررسی کنید.")

# نصب rubberband-cli اگر نصب نیست
# !apt-get install -y rubberband-cli

await generate_speech()

# %%
#@title شروع عملیات نهایی (بهبود یافته)
import subprocess
import pysrt
import os
from datetime import timedelta
import json
from pydub import AudioSegment
import tempfile
import glob

# بررسی و پیدا کردن فایل ویدیو با هر فرمتی
video_files = glob.glob('input_video.*')
if not os.path.exists('input_video.mp4') and video_files:
    input_video = video_files[0]
else:
    input_video = 'input_video.mp4'

#@markdown #### تنظیمات صدای اصلی
#@markdown آیا می‌خواهید صدای اصلی ویدیو حفظ شود؟
keep_original_audio = False #@param {type:"boolean"}
#@markdown میزان صدای اصلی ویدیو (فقط در صورت فعال بودن گزینه بالا)
original_audio_volume = 0.015 #@param {type:"slider", min:0, max:1, step:0.005}
#@markdown #### روش ترکیب صدا
audio_merge_method = "pydub" #@param ["ffmpeg concat", "ffmpeg filter_complex", "pydub"]

# بررسی وجود فایل‌های مورد نیاز
if not os.path.exists(input_video):
    print(f"خطا: فایل {input_video} یافت نشد!")
    print("لطفاً نام ویدیوی ورودی را بررسی کنید")
else:
    print(f"✓ فایل ویدیو یافت شد: {input_video}")

if not os.path.exists('/content/audio_fa.srt'):
    print("خطا: فایل زیرنویس یافت نشد!")
else:
    print("✓ فایل زیرنویس یافت شد")

# بررسی وجود پوشه سگمنت‌ها
segment_dir = "dubbing_project/dubbed_segments"
if not os.path.exists(segment_dir):
    print("خطا: پوشه سگمنت‌های صوتی یافت نشد!")
    os.makedirs(segment_dir, exist_ok=True)
else:
    segments = [f for f in os.listdir(segment_dir) if f.startswith("dub_") and f.endswith(".wav")]
    print(f"✓ {len(segments)} سگمنت صوتی یافت شد")

# خواندن و پردازش فایل زیرنویس
try:
    subs = pysrt.open('/content/audio_fa.srt', encoding='utf-8')
    print("✓ فایل زیرنویس با موفقیت خوانده شد")
except UnicodeDecodeError:
    try:
        subs = pysrt.open('/content/audio_fa.srt', encoding='latin-1')
        print("✓ فایل زیرنویس با encoding=latin-1 خوانده شد")
    except Exception as e:
        print(f"خطا در خواندن فایل زیرنویس: {str(e)}")
        print("در حال تلاش مجدد...")
        try:
            subprocess.run(['iconv', '-f', 'ISO-8859-1', '-t', 'UTF-8', '/content/audio_fa.srt', '-o', '/content/audio_fa_utf8.srt'])
            subs = pysrt.open('/content/audio_fa_utf8.srt')
            print("✓ فایل زیرنویس با تبدیل به UTF-8 خوانده شد")
        except:
            print("خطا در خواندن فایل زیرنویس!")
            exit()

# استخراج کد زبان از voice_choice برای نام فایل
voice_choice = os.environ.get('voice_choice', "دلارا (FA)")
voice_code = voice_choice.split("(")[1].split(")")[0] if "(" in voice_choice else "FA"
output_filename = f'final_dubbed_video_{voice_code}.mp4'

# برای اطمینان از پاک شدن فایل خروجی قبلی
if os.path.exists(output_filename):
    os.remove(output_filename)
    print(f"✓ فایل خروجی قبلی '{output_filename}' حذف شد")

# روش 1: استفاده از فایل concat
if audio_merge_method == "ffmpeg concat":
    print("در حال استفاده از روش ffmpeg concat...")

    try:
        temp_dir = tempfile.mkdtemp()
        segment_info_file = os.path.join(temp_dir, "segments.txt")

        # استخراج صدای اصلی
        original_audio_path = os.path.join(temp_dir, "original_audio.wav")
        subprocess.run([
            'ffmpeg', '-i', input_video, '-vn',
            '-acodec', 'pcm_s16le', '-ar', '44100', '-ac', '2',
            original_audio_path
        ], check=True)

        # تنظیم میزان صدای اصلی
        modified_original_audio = os.path.join(temp_dir, "original_audio_modified.wav")
        volume = original_audio_volume if keep_original_audio else 0.0
        subprocess.run([
            'ffmpeg', '-i', original_audio_path,
            '-filter:a', f'volume={volume}',
            modified_original_audio
        ], check=True)

        # ایجاد فایل خروجی با آدیو ترکیب شده
        with open(segment_info_file, 'w') as f:
            for i, sub in enumerate(subs):
                start_time_ms = (sub.start.hours * 3600 + sub.start.minutes * 60 + sub.start.seconds) * 1000 + sub.start.milliseconds
                start_time_sec = start_time_ms / 1000.0

                segment_path = f"dubbing_project/dubbed_segments/dub_{i+1}.wav"
                if os.path.exists(segment_path):
                    f.write(f"file '{segment_path}'\n")
                    f.write(f"inpoint {start_time_sec}\n")

        # ترکیب سگمنت‌ها با صدای اصلی
        merged_audio = os.path.join(temp_dir, "merged_audio.wav")
        dubbing_audio = os.path.join(temp_dir, "dubbing_audio.wav")

        subprocess.run([
            'ffmpeg', '-f', 'concat', '-safe', '0',
            '-i', segment_info_file, '-c', 'copy', dubbing_audio
        ], check=True)

        subprocess.run([
            'ffmpeg',
            '-i', modified_original_audio,
            '-i', dubbing_audio,
            '-filter_complex', '[0:a][1:a]amix=inputs=2:duration=longest',
            merged_audio
        ], check=True)

        subprocess.run([
            'ffmpeg', '-i', input_video, '-i', merged_audio,
            '-c:v', 'copy', '-c:a', 'aac', '-map', '0:v', '-map', '1:a',
            output_filename
        ], check=True)

        print(f"✓ ویدیو با موفقیت با روش concat ساخته شد: {output_filename}")
        from google.colab import files
        files.download(output_filename)

    except Exception as e:
        print(f"خطا در روش concat: {str(e)}")
        print("در حال امتحان روش جایگزین...")
        audio_merge_method = "pydub"

# روش 2: استفاده از filter_complex
if audio_merge_method == "ffmpeg filter_complex":
    print("در حال استفاده از روش ffmpeg filter_complex...")

    try:
        if keep_original_audio:
            filter_complex = f"[0:a]volume={original_audio_volume}[original_audio];"
        else:
            filter_complex = "[0:a]volume=0[original_audio];"

        valid_segments = []
        for i, sub in enumerate(subs):
            segment_path = f"dubbing_project/dubbed_segments/dub_{i+1}.wav"
            if os.path.exists(segment_path):
                try:
                    start_time_ms = (sub.start.hours * 3600 + sub.start.minutes * 60 + sub.start.seconds) * 1000 + sub.start.milliseconds
                    if start_time_ms < 0:
                        start_time_ms = 0
                    filter_complex += f"[{i+1}:a]adelay={start_time_ms}|{start_time_ms}[a{i+1}];"
                    valid_segments.append(i)
                except Exception as e:
                    print(f"رد کردن سگمنت {i+1} به دلیل مشکل: {str(e)}")
                    continue

        if valid_segments:
            merge_command = "[original_audio]"
            for i in valid_segments:
                merge_command += f"[a{i+1}]"
            merge_command += f"amix=inputs={len(valid_segments) + 1}:normalize=0[aout]"
            filter_complex += merge_command

            input_files = f"-i {input_video} " + " ".join([f"-i dubbing_project/dubbed_segments/dub_{i+1}.wav" for i in valid_segments])
            command = f"ffmpeg -y {input_files} -filter_complex \"{filter_complex}\" -map 0:v -map \"[aout]\" -c:v copy -c:a aac {output_filename}"

            result = subprocess.run(command, shell=True, capture_output=True, text=True)
            print("خروجی ffmpeg (filter_complex):")
            print(result.stdout)
            print("خطاهای ffmpeg (filter_complex):")
            print(result.stderr)

            if os.path.exists(output_filename):
                print(f"✓ ویدیو با موفقیت با روش filter_complex ساخته شد: {output_filename}")
                from google.colab import files
                files.download(output_filename)
            else:
                raise Exception("فایل خروجی ساخته نشد!")
        else:
            print("خطا: هیچ سگمنت صوتی معتبری یافت نشد!")
            audio_merge_method = "pydub"

    except Exception as e:
        print(f"خطا در روش filter_complex: {str(e)}")
        print("در حال امتحان روش جایگزین...")
        audio_merge_method = "pydub"

# روش 3: استفاده از pydub
if audio_merge_method == "pydub":
    print("در حال استفاده از روش pydub...")

    try:
        temp_dir = tempfile.mkdtemp()
        original_audio_path = os.path.join(temp_dir, "original_audio.wav")
        subprocess.run([
            'ffmpeg', '-i', input_video, '-vn',
            '-acodec', 'pcm_s16le', '-ar', '44100', '-ac', '2',
            original_audio_path
        ], check=True)

        original_audio = AudioSegment.from_file(original_audio_path)
        if keep_original_audio:
            original_audio = original_audio - (20 - (20 * original_audio_volume))
        else:
            original_audio = AudioSegment.silent(duration=len(original_audio))

        final_audio = original_audio
        for i, sub in enumerate(subs):
            segment_path = f"dubbing_project/dubbed_segments/dub_{i+1}.wav"
            if os.path.exists(segment_path):
                try:
                    segment_audio = AudioSegment.from_file(segment_path)
                    start_time_ms = (sub.start.hours * 3600 + sub.start.minutes * 60 + sub.start.seconds) * 1000 + sub.start.milliseconds
                    if start_time_ms < 0:
                        start_time_ms = 0
                    final_audio = final_audio.overlay(segment_audio, position=start_time_ms)
                    print(f"سگمنت {i+1} در زمان {start_time_ms}ms اضافه شد")
                except Exception as e:
                    print(f"خطا در اضافه کردن سگمنت {i+1}: {str(e)}")

        merged_audio_path = os.path.join(temp_dir, "merged_audio.wav")
        final_audio.export(merged_audio_path, format="wav")

        subprocess.run([
            'ffmpeg', '-i', input_video, '-i', merged_audio_path,
            '-c:v', 'copy', '-c:a', 'aac', '-map', '0:v', '-map', '1:a',
            output_filename
        ], check=True)

        print(f"✓ ویدیو با موفقیت با روش pydub ساخته شد: {output_filename}")
        from google.colab import files
        files.download(output_filename)

    except Exception as e:
        print(f"خطا در روش pydub: {str(e)}")
        print("لطفاً خطا را بررسی کنید، هیچ روش دیگری باقی نمانده است!")

# پاکسازی فایل‌های موقت
if os.path.exists(temp_dir):
    import shutil
    shutil.rmtree(temp_dir)
    print("✓ فایل‌های موقت پاک شدند")

# %%
#@title پاکسازی فایل‌های جلسه قبلی
# !rm -rf /content/*
